# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_rows', None)

# %%
pd.set_option('display.max_columns', None)

# %%
plt.rcParams["axes.labelsize"] = 15

# %%
df = pd.read_csv('../data/data_2022-03-31_23_07_32.csv', sep=';')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12329 entries, 0 to 12328
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    12329 non-null  int64
#  1   Precio (€/mes)        12329 non-null  int64
#  2   Tipo                  12329 non-null  object
#  3   Teléfono              12329 non-null  object
#  4   Ciudad                12329 non-null  object
#  5   Dirección             7726 non-null   object
#  6   Barrio                12329 non-null  object
#  7   Habitaciones          11923 non-null  float64
#  8   Baños                 12212 non-null  float64
#  9   Superficie (m2)       12295 non-null  float64
#  10  Planta                6407 non-null   float64
#  11  Ascensor              12329 non-null  bool
#  12  Terraza               12329 non-null  bool
#  13  Parking               12329 non-null  bool
#  14  Calefacción           12329 non-null  bool
# ...

# %%
df.describe(include='all')
# Out:
#                   ID  Precio (€/mes)   Tipo Teléfono          Ciudad  \
# count   1.232900e+04    1.232900e+04  12329    12329           12329
# unique           NaN             NaN     11     1614               5
# top              NaN             NaN   Piso  Unknown  Madrid Capital
# freq             NaN             NaN   8863     1422            5630
# mean    1.618412e+08    2.671155e+03    NaN      NaN             NaN
# std     2.098941e+06    3.899180e+04    NaN      NaN             NaN
# min     1.281334e+08    4.000000e+01    NaN      NaN             NaN
# 25%     1.617000e+08    8.500000e+02    NaN      NaN             NaN
# 50%     1.626748e+08    1.200000e+03    NaN      NaN             NaN
# 75%     1.629642e+08    1.800000e+03    NaN      NaN             NaN
# max     1.631213e+08    2.200000e+06    NaN      NaN             NaN
#
#                        Dirección  Barrio  Habitaciones         Baños  \
# ...

# %%
df.nunique()
# Out:
# ID                      12329
# Precio (€/mes)           1046
# Tipo                       11
# Teléfono                 1614
# Ciudad                      5
# Dirección                4264
# Barrio                     92
# Habitaciones               13
# Baños                       9
# Superficie (m2)           400
# Planta                     15
# Ascensor                    2
# Terraza                     2
# Parking                     2
# Calefacción                 2
# Aire                        2
# Balcón                      2
# Precio del m2 (€/m2)     4106
# dtype: int64

# %%
df.head()
# Out:
#           ID  Precio (€/mes)  Tipo   Teléfono             Ciudad  \
# 0  163001940            1000  Piso  932992519  Barcelona Capital
# 1  162374941            1210  Piso  931337036  Barcelona Capital
# 2  162691725            1575  Piso  931332815  Barcelona Capital
# 3  163058375             790  Piso  932995389  Barcelona Capital
# 4  163052942            1050  Piso  932995389  Barcelona Capital
#
#                   Dirección            Barrio  Habitaciones  Baños  \
# 0  Carrer de L'arquitectura  Horta - Guinardó           2.0    1.0
# 1          Carrer la Rambla      Ciutat Vella           1.0    1.0
# 2             Roger de Flor          Eixample           3.0    2.0
# 3           Carrer de Pelai          Eixample           1.0    1.0
# 4       Rambla de Catalunya          Eixample           1.0    1.0
#
#    Superficie (m2)  Planta  Ascensor  Terraza  Parking  Calefacción   Aire  \
# 0             85.0     3.0     False    False     True         True  False
# ...

# %%
df.tail()
# Out:
#               ID  Precio (€/mes)         Tipo   Teléfono           Ciudad  \
# 12324  158022416             550  Apartamento  958916915  Granada Capital
# 12325  155411694             500         Piso  958916851  Granada Capital
# 12326  155411682             750         Piso  958916851  Granada Capital
# 12327  155412410            1000         Piso  958916851  Granada Capital
# 12328  155412464             950         Piso  958916851  Granada Capital
#
#                   Dirección    Barrio  Habitaciones  Baños  Superficie (m2)  \
# 12324        Calle Abenamar    Centro           1.0    1.0             50.0
# 12325              Einstein     Ronda           1.0    1.0             50.0
# 12326  Calle Gonzalo Gallas     Ronda           3.0    2.0            100.0
# 12327                Elvira  Albaicín           4.0    2.0            150.0
# 12328        Madre Riquelme    Centro           4.0    3.0            130.0
#
# ...

# %%
# List with numeric attributes
num_attrs = ['Precio (€/mes)', 'Habitaciones', 'Baños', 'Superficie (m2)', 'Planta', 'Precio del m2 (€/m2)']

# %%
fig, ax = plt.subplots(nrows=1, ncols=len(num_attrs), figsize=(30,6), sharex=True)

for n, num in enumerate(num_attrs):
    g = sns.boxplot(data=df, x='Ciudad', y=num, palette="tab10", ax=ax[n])
    g.set_xticklabels(g.get_xticklabels(), rotation=45, fontsize=12)
    g.grid()
fig.tight_layout()
plt.show()

# %%
def remove_outliers(df, cols, r=1.5):
    Q1 = df[cols].quantile(0.25)
    Q3 = df[cols].quantile(0.75)
    IQR = Q3 - Q1

    df = df[~((df[cols] < (Q1 - r * IQR)) | (df[cols] > (Q3 + r * IQR))).any(axis=1)]
    
    return df

# %%
df = remove_outliers(df, num_attrs, r=1.5)

# %%
fig, ax = plt.subplots(nrows=1, ncols=int(len(num_attrs)), figsize=(30,6), sharex=True)

for n, num in enumerate(num_attrs):
    g = sns.boxplot(data=df, x='Ciudad', y=num, palette='tab10', ax=ax[n])
    g.set_xticklabels(g.get_xticklabels(), rotation=45, fontsize=12)
    g.grid()
fig.tight_layout()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10156 entries, 0 to 12328
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    10156 non-null  int64
#  1   Precio (€/mes)        10156 non-null  int64
#  2   Tipo                  10156 non-null  object
#  3   Teléfono              10156 non-null  object
#  4   Ciudad                10156 non-null  object
#  5   Dirección             6327 non-null   object
#  6   Barrio                10156 non-null  object
#  7   Habitaciones          9805 non-null   float64
#  8   Baños                 10056 non-null  float64
#  9   Superficie (m2)       10122 non-null  float64
#  10  Planta                5465 non-null   float64
#  11  Ascensor              10156 non-null  bool
#  12  Terraza               10156 non-null  bool
#  13  Parking               10156 non-null  bool
#  14  Calefacción           10156 non-null  bool
# ...

# %%
fig, ax = plt.subplots(figsize=(15,6))
sns.histplot(df, x='Precio (€/mes)', hue='Ciudad', stat="density",
             palette='tab10', alpha=.3, common_norm=True, ax=ax)
ax.grid(alpha=.3)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,6))
sns.kdeplot(x=df['Precio (€/mes)'], hue=df['Ciudad'], fill=True,
            common_norm=False, palette="tab10", linewidth=1.5, alpha=.25)
ax.grid(alpha=.3)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,6))
sns.histplot(df, x='Precio (€/mes)', hue='Ciudad', stat="density",
             palette='tab10', alpha=.3, common_norm=True, ax=ax)
sns.kdeplot(x=df['Precio (€/mes)'], hue=df['Ciudad'], fill=True,
            common_norm=True, palette="tab10", linewidth=1.5, alpha=.1)
ax.grid(alpha=.3)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,6))
sns.histplot(df, x='Habitaciones', hue='Ciudad', stat="probability", multiple="dodge",
             shrink=5, palette='tab10', alpha=.7, common_norm=False, ax=ax)
ax.grid(alpha=.3)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,6))
sns.histplot(df, x='Baños', hue='Ciudad', stat="probability", multiple="dodge",
             shrink=5, palette='tab10', alpha=.7, common_norm=False, ax=ax)
ax.grid(alpha=.3)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,6))
sns.histplot(df, x='Superficie (m2)', hue='Ciudad', stat="density",
             palette='tab10', alpha=.3, common_norm=True, ax=ax)
ax.grid(alpha=.3)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,6))
sns.kdeplot(x=df['Superficie (m2)'], hue=df['Ciudad'], fill=True,
            common_norm=False, palette="tab10", linewidth=1.5, alpha=.25)
ax.grid(alpha=.3)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,6))
sns.histplot(df, x='Superficie (m2)', hue='Ciudad', stat="density",
             palette='tab10', alpha=.3, common_norm=True, ax=ax)
sns.kdeplot(x=df['Superficie (m2)'], hue=df['Ciudad'], fill=True,
            common_norm=True, palette="tab10", linewidth=1.5, alpha=.1)
ax.grid(alpha=.3)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,6))
sns.histplot(df, x='Planta', hue='Ciudad', stat="probability", multiple="dodge",
             shrink=1.5, palette='tab10', alpha=.7, common_norm=False, ax=ax)
ax.set_xticks(range(int(np.min(df['Planta'])), int(np.max(df['Planta'])) + 1))
ax.grid(alpha=.3)
plt.show()

# %%
atts = ['Ascensor', 'Terraza', 'Parking', 'Calefacción', 'Aire', 'Balcón']
for att in atts:
    fig, ax = plt.subplots(figsize=(15,6))
    sns.histplot(df, x='Ciudad', hue=att, stat="probability", multiple="dodge",
                 shrink=0.8, palette='Set1', alpha=.7, common_norm=True, ax=ax)
    ax.grid(alpha=.3)
    plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,6))
sns.histplot(df, x='Precio del m2 (€/m2)', hue='Ciudad', stat="density",
             palette='tab10', alpha=.3, common_norm=True, ax=ax)
ax.grid(alpha=.3)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,6))
sns.kdeplot(x=df['Precio del m2 (€/m2)'], hue=df['Ciudad'], fill=True,
            common_norm=False, palette="tab10", linewidth=1.5, alpha=.25)
ax.grid(alpha=.3)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,6))
sns.histplot(df, x='Precio del m2 (€/m2)', hue='Ciudad', stat="density",
             palette='tab10', alpha=.3, common_norm=True, ax=ax)
sns.kdeplot(x=df['Precio del m2 (€/m2)'], hue=df['Ciudad'], fill=True,
            common_norm=True, palette="tab10", linewidth=1.5, alpha=.1)
ax.grid(alpha=.3)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))

sns.histplot(df['Precio (€/mes)'], stat='count', color='lightgreen',
             kde=True, ax=ax, lw=1.5, alpha=0.7)

ax.lines[0].set_linewidth(2)
ax.lines[0].set_color('blue')
ax.axvline(x=np.mean(df['Precio (€/mes)']), color='red', lw=1.5, label='mean')
ax.axvline(x=np.median(df['Precio (€/mes)']), color='purple', lw=1.5, label='median')
ax.legend()
ax.grid(c='k', alpha=0.3)
ax.set_title(f'HISTOGRAM OF "Precio (€/mes)"')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))

sns.histplot(df['Precio (€/mes)'], stat='probability', color='lightgreen',
             kde=True, ax=ax, lw=1.5, alpha=0.7)

ax.lines[0].set_linewidth(2)
ax.lines[0].set_color('blue')
ax.axvline(x=np.mean(df['Precio (€/mes)']), color='red', lw=1.5, label='mean')
ax.axvline(x=np.median(df['Precio (€/mes)']), color='purple', lw=1.5, label='median')
ax.legend()
ax.grid(c='k', alpha=0.3)
ax.set_title(f'NORMALIZED HISTOGRAM OF "Precio (€/mes)"')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))

freq = pd.crosstab(index=df['Tipo'], columns='freq', normalize=False)
freq.plot(kind='bar', ax=ax, alpha=0.7, rot=60,
          ec='k', lw=1.5, legend=False,
          title=f'HISTOGRAM OF "Tipo"')
ax.set_ylabel('Count')
ax.grid(c='k', alpha=0.3)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))

freq = pd.crosstab(index=df['Tipo'], columns='freq', normalize=True)
freq.plot(kind='bar', ax=ax, alpha=0.7, rot=60,
          ec='k', lw=1.5, legend=False,
          title=f'NORMALIZED HISTOGRAM OF "Tipo"')
ax.set_ylabel('Probability')
ax.grid(c='k', alpha=0.3)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(35,6))

freq = pd.crosstab(index=df['Barrio'], columns='freq', normalize=False)
freq.plot(kind='bar', ax=ax, alpha=0.7, rot=60,
          ec='k', lw=1.5, legend=False,
          title=f'HISTOGRAM OF "Barrio"')
ax.set_ylabel('Count')
ax.grid(c='k', alpha=0.3)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(35,6))

freq = pd.crosstab(index=df['Barrio'], columns='freq', normalize=True)
freq.plot(kind='bar', ax=ax, alpha=0.7, rot=60,
          ec='k', lw=1.5, legend=False,
          title=f'NORMALIZED HISTOGRAM OF "Barrio"')
ax.set_ylabel('Probability')
ax.grid(c='k', alpha=0.3)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))

freq = pd.crosstab(index=df['Habitaciones'], columns='freq', normalize=False)
freq.plot(kind='bar', ax=ax, alpha=0.7, rot=0,
          ec='k', lw=1.5, legend=False,
          title=f'HISTOGRAM OF "Habitaciones"')
ax.set_ylabel('Count')
ax.grid(c='k', alpha=0.3)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))

freq = pd.crosstab(index=df['Habitaciones'], columns='freq', normalize=True)
freq.plot(kind='bar', ax=ax, alpha=0.7, rot=0,
          ec='k', lw=1.5, legend=False,
          title=f'NORMALIZED HISTOGRAM OF "Habitaciones"')
ax.set_ylabel('Probability')
ax.grid(c='k', alpha=0.3)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))

freq = pd.crosstab(index=df['Baños'], columns='freq', normalize=False)
freq.plot(kind='bar', ax=ax, alpha=0.7, rot=0,
          ec='k', lw=1.5, legend=False,
          title=f'HISTOGRAM OF "Baños"')
ax.set_ylabel('Count')
ax.grid(c='k', alpha=0.3)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))

freq = pd.crosstab(index=df['Baños'], columns='freq', normalize=True)
freq.plot(kind='bar', ax=ax, alpha=0.7, rot=0,
          ec='k', lw=1.5, legend=False,
          title=f'NORMALIZED HISTOGRAM OF "Baños"')
ax.set_ylabel('Probability')
ax.grid(c='k', alpha=0.3)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))

sns.histplot(df['Superficie (m2)'], stat='count', color='lightgreen',
             kde=True, ax=ax, lw=1.5, alpha=0.7)

ax.lines[0].set_linewidth(2)
ax.lines[0].set_color('blue')
ax.axvline(x=np.mean(df['Superficie (m2)']), color='red', lw=1.5, label='mean')
ax.axvline(x=np.median(df['Superficie (m2)']), color='purple', lw=1.5, label='median')
ax.legend()
ax.grid(c='k', alpha=0.3)
ax.set_title(f'HISTOGRAM OF "Superficie (m2)"')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))

sns.histplot(df['Superficie (m2)'], stat='probability', color='lightgreen',
             kde=True, ax=ax, lw=1.5, alpha=0.7)

ax.lines[0].set_linewidth(2)
ax.lines[0].set_color('blue')
ax.axvline(x=np.mean(df['Superficie (m2)']), color='red', lw=1.5, label='mean')
ax.axvline(x=np.median(df['Superficie (m2)']), color='purple', lw=1.5, label='median')
ax.legend()
ax.grid(c='k', alpha=0.3)
ax.set_title(f'NORMALIZED HISTOGRAM OF "Superficie (m2)"')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))

freq = pd.crosstab(index=df['Ascensor'], columns='freq', normalize=False)
freq.plot(kind='bar', ax=ax, alpha=0.7, rot=0,
          ec='k', lw=1.5, legend=False,
          title=f'HISTOGRAM OF "Ascensor"')
ax.set_ylabel('Count')
ax.grid(c='k', alpha=0.3)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))

freq = pd.crosstab(index=df['Ascensor'], columns='freq', normalize=True)
freq.plot(kind='bar', ax=ax, alpha=0.7, rot=0,
          ec='k', lw=1.5, legend=False,
          title=f'NORMALIZED HISTOGRAM OF "Ascensor"')
ax.set_ylabel('Probability')
ax.grid(c='k', alpha=0.3)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))

freq = pd.crosstab(index=df['Terraza'], columns='freq', normalize=False)
freq.plot(kind='bar', ax=ax, alpha=0.7, rot=0,
          ec='k', lw=1.5, legend=False,
          title=f'HISTOGRAM OF "Terraza"')
ax.set_ylabel('Count')
ax.grid(c='k', alpha=0.3)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))

freq = pd.crosstab(index=df['Terraza'], columns='freq', normalize=True)
freq.plot(kind='bar', ax=ax, alpha=0.7, rot=0,
          ec='k', lw=1.5, legend=False,
          title=f'NORMALIZED HISTOGRAM OF "Terraza"')
ax.set_ylabel('Probability')
ax.grid(c='k', alpha=0.3)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))

freq = pd.crosstab(index=df['Parking'], columns='freq', normalize=False)
freq.plot(kind='bar', ax=ax, alpha=0.7, rot=0,
          ec='k', lw=1.5, legend=False,
          title=f'HISTOGRAM OF "Parking"')
ax.set_ylabel('Count')
ax.grid(c='k', alpha=0.3)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))

freq = pd.crosstab(index=df['Parking'], columns='freq', normalize=True)
freq.plot(kind='bar', ax=ax, alpha=0.7, rot=0,
          ec='k', lw=1.5, legend=False,
          title=f'NORMALIZED HISTOGRAM OF "Parking"')
ax.set_ylabel('Probability')
ax.grid(c='k', alpha=0.3)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))

freq = pd.crosstab(index=df['Calefacción'], columns='freq', normalize=False)
freq.plot(kind='bar', ax=ax, alpha=0.7, rot=0,
          ec='k', lw=1.5, legend=False,
          title=f'HISTOGRAM OF "Calefacción"')
ax.set_ylabel('Count')
ax.grid(c='k', alpha=0.3)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))

freq = pd.crosstab(index=df['Calefacción'], columns='freq', normalize=True)
freq.plot(kind='bar', ax=ax, alpha=0.7, rot=0,
          ec='k', lw=1.5, legend=False,
          title=f'NORMALIZED HISTOGRAM OF "Calefacción"')
ax.set_ylabel('Probability')
ax.grid(c='k', alpha=0.3)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))

freq = pd.crosstab(index=df['Aire'], columns='freq', normalize=False)
freq.plot(kind='bar', ax=ax, alpha=0.7, rot=0,
          ec='k', lw=1.5, legend=False,
          title=f'HISTOGRAM OF "Aire"')
ax.set_ylabel('Count')
ax.grid(c='k', alpha=0.3)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))

freq = pd.crosstab(index=df['Aire'], columns='freq', normalize=True)
freq.plot(kind='bar', ax=ax, alpha=0.7, rot=0,
          ec='k', lw=1.5, legend=False,
          title=f'NORMALIZED HISTOGRAM OF "Aire"')
ax.set_ylabel('Probability')
ax.grid(c='k', alpha=0.3)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))

freq = pd.crosstab(index=df['Balcón'], columns='freq', normalize=False)
freq.plot(kind='bar', ax=ax, alpha=0.7, rot=0,
          ec='k', lw=1.5, legend=False,
          title=f'HISTOGRAM OF "Balcón"')
ax.set_ylabel('Count')
ax.grid(c='k', alpha=0.3)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))

freq = pd.crosstab(index=df['Balcón'], columns='freq', normalize=True)
freq.plot(kind='bar', ax=ax, alpha=0.7, rot=0,
          ec='k', lw=1.5, legend=False,
          title=f'NORMALIZED HISTOGRAM OF "Balcón"')
ax.set_ylabel('Probability')
ax.grid(c='k', alpha=0.3)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))

freq = pd.crosstab(index=df['Planta'], columns='freq', normalize=False)
freq.plot(kind='bar', ax=ax, alpha=0.7, rot=0,
          ec='k', lw=1.5, legend=False,
          title=f'HISTOGRAM OF "Planta"')
ax.set_ylabel('Count')
ax.grid(c='k', alpha=0.3)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))

freq = pd.crosstab(index=df['Planta'], columns='freq', normalize=True)
freq.plot(kind='bar', ax=ax, alpha=0.7, rot=0,
          ec='k', lw=1.5, legend=False,
          title=f'NORMALIZED HISTOGRAM OF "Planta"')
ax.set_ylabel('Probability')
ax.grid(c='k', alpha=0.3)

plt.show()

# %%
df[(df['Habitaciones'] > 1) & (df['Precio (€/mes)'] < np.mean(df['Precio (€/mes)'])) & (df['Terraza'] == 1)]
# Out:
#               ID  Precio (€/mes)           Tipo   Teléfono             Ciudad  \
# 11     163026103            1200           Piso  932995389  Barcelona Capital
# 106    162718913            1150           Piso  932886591  Barcelona Capital
# 117    161310753             950          Ático  931339854  Barcelona Capital
# 120    162205459             850           Piso  931338715  Barcelona Capital
# 121    161177601            1150          Ático  935430293  Barcelona Capital
# 136    163012717             900           Piso  931333829  Barcelona Capital
# 152    163015373            1025           Piso  935439838  Barcelona Capital
# 289    162538427             925           Piso  935439838  Barcelona Capital
# 400    163105393            1050           Piso  932516412  Barcelona Capital
# 560    163062729             859    Apartamento  966530983  Barcelona Capital
# 630    163118294            1100           Piso  931333618  Barcelona Capital
# ...

# %%
def corr_matrix(df):
    '''
    Returns a plot (heatmap) of the diagonal correlation matrix for all
    the variables in the dataframe 'df'.

            Parameters:
                    df (dataframe): Dataframe containing the data
    '''

    #Correlation matrix
    df_corr = df.corr()

    #Figure and axis
    fig, ax = plt.subplots(figsize=(15, 10))
    #Mask
    mask = np.triu(np.ones_like(df_corr, dtype=bool))
    #Adjust mask and df
    mask = mask[1:, :-1]
    corr = df_corr.iloc[1:,:-1].copy()
    #Color map
    cmap = sns.diverging_palette(0, 300, 800, 70, as_cmap=True)

    #Plot heatmap
    sns.heatmap(corr, mask=mask, annot=True, fmt=".2f",
               linewidths=5, cmap=cmap, vmin=-1, vmax=1,
               cbar_kws={"shrink": .8}, square=True)

    #Ticks
    yticks = [i.upper() for i in corr.index]
    xticks = [i.upper() for i in corr.columns]
    plt.yticks(plt.yticks()[0], labels=yticks, rotation=0)
    plt.xticks(plt.xticks()[0], labels=xticks, rotation=45)
    #Title
    plt.title('CORRELATION MATRIX', fontsize=25)
    plt.show()
    return


#All variables correlations
corr_matrix(df)

# %%
def corr_matrix_one_vs_all(df, var):
    '''
    Returns a plot (heatmap) of the correlation matrix with the
    correlations between the variable 'var' and all the other
    variables in the dataframe 'df'.

            Parameters:
                    df (dataframe): Dataframe containing the data
                    var (string): Name of the variable to consider its correlations
    '''

    #Correlation matrix
    df_corr = df.corr()
    #Correlation matrix with var
    df_corr_var = pd.DataFrame(df_corr[var].sort_values(ascending=False))

    #Figure and axis
    fig, ax = plt.subplots(figsize=(15, 10))
    #Mask
    mask_var = np.zeros_like(df_corr_var, dtype=bool)
    mask_var[0] = True
    #Adjust mask and df
    mask_var = mask_var[1:]
    corr_var = df_corr_var.iloc[1:].copy()
    #Color map
    cmap = sns.diverging_palette(0, 300, 800, 70, as_cmap=True)

    #Plot heatmap
    sns.heatmap(corr_var, mask=mask_var, annot=True, fmt=".2f",
               linewidths=5, cmap=cmap, vmin=-1, vmax=1,
               cbar_kws={"shrink": .8}, square=True)

    #Ticks
    yticks = [i.upper() for i in corr_var.index]
    xticks = [i.upper() for i in corr_var.columns]
    plt.yticks(plt.yticks()[0], labels=yticks, rotation=0)
    plt.xticks(plt.xticks()[0], labels=xticks, rotation=0)
    #Title
    plt.title(f'FEATURES CORRELATING WITH {var.upper()}\n', fontsize=20)
    plt.show()
    return


#Features correlating with Price
corr_matrix_one_vs_all(df, 'Precio (€/mes)')

# %%
sns.pairplot(df, hue='Ciudad', vars=num_attrs, diag_kws={'alpha':0.5},
             palette='Set2', plot_kws={'s':20, 'alpha':0.4, 'ec':'k'},
             corner=True)
plt.show()
